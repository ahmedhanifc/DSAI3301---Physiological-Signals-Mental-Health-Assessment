# %%
import pandas as pd
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
def draw_plots(df, column):
    df.index = pd.to_datetime(df.index)

    fig, ax = plt.subplots(figsize=(12, 8))
    ax.plot(df.index, df[column])

    # Define the locator as before to control tick frequency
    locator = mdates.MonthLocator() # Explicitly locate ticks at the start of each month
    
    # Replace ConciseDateFormatter with the explicit DateFormatter
    formatter = mdates.DateFormatter('%b %Y') # Format: Abbreviated Month and Full Year

    ax.xaxis.set_major_locator(locator)
    ax.xaxis.set_major_formatter(formatter)
    
    fig.autofmt_xdate(rotation=45) # rotation for better spacing
    
    plt.show()

def draw_plots_grid(df, columns,  windows=[7, 28],save_path = "",nrows = 2, ncols = 2):

    df.index = pd.to_datetime(df.index)

    # Create a 2x2 grid of subplots. 'ax' is now a 2x2 NumPy array.
    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(20, 16))

    # Flatten the 2D array of axes to a 1D array for easy iteration.
    axes_flat = ax.flatten()

    # Loop through each column and its corresponding subplot axis.
    for i, col_name in enumerate(columns):
        # Select the current axis from the flattened array.
        current_ax = axes_flat[i]
        
        # Plot the data on the current axis.
        current_ax.plot(df.index, df[col_name], label = "original")
        colors = ['orange', 'red', 'green'] 
        for j, window_size in enumerate(windows):
            rolling_mean = df[col_name].rolling(window=window_size).mean()
            current_ax.plot(df.index, rolling_mean, label=f'{window_size}-Day Avg', color=colors[j], linewidth=2 + j)
        
        # Set a title for the individual subplot.
        current_ax.set_title(f"Time Series of {col_name}")

        # Define locator and formatter for THIS specific subplot's x-axis.
        locator = mdates.MonthLocator()
        formatter = mdates.DateFormatter('%b %Y')

        current_ax.xaxis.set_major_locator(locator)
        current_ax.xaxis.set_major_formatter(formatter)
        current_ax.legend()
        current_ax.grid(True, linestyle='--', alpha=0.6)

    fig.tight_layout(pad=3.0)
    
    for i in range(len(columns), len(axes_flat)):
        axes_flat[i].set_visible(False)

    if(save_path):
        plt.savefig(save_path, dpi = 300)
    plt.show()

# %%
def analyze_gaps(df, column_name):
    """
    Analyzes the structure of contiguous missing value gaps in a DataFrame column.
    """
    is_missing = df[column_name].isnull()
    if not is_missing.any():
        return {
            "num_gaps":0,
            "max_gap_length":0,
            "avg_gap_length":0
        }
        
    gap_starts = is_missing.ne(is_missing.shift()).cumsum()
    gaps = is_missing.groupby(gap_starts).sum()
    actual_gaps = gaps[gaps > 0]
    if actual_gaps.empty:
        return {
            'num_gaps': 0,
            'max_gap_length': 0,
            'avg_gap_length': 0.0
        }
        
    return {
        'num_gaps': len(actual_gaps),
        'max_gap_length': actual_gaps.max(),
        'avg_gap_length': actual_gaps.mean()
    }

# %%
def plot_missing_values_heatmap(df, save_path= ""):
    plt.figure(figsize=(20, 10))
    sns.heatmap(df.isnull(), cbar = False, yticklabels = False, cmap = "viridis")
    plt.title('Heatmap of Missing Values by Time', fontsize=16)
    plt.xlabel('Features')
    plt.ylabel('Time (Chronological Order)')
    if(save_path):
        plt.savefig(f"./figures/{save_path}")
    plt.show()

def plot_missing_values_correlation(df, save_path= ""):
    numeric_columns = df.select_dtypes(include = np.number).columns
    plt.figure(figsize=(18, 15))
    sns.heatmap(df[numeric_columns].isnull().corr(), cmap='coolwarm')
    plt.title('Correlation Matrix of Missing Values')
    if(save_path):
        plt.savefig(f"./figures/{save_path}")
    plt.show()

# %%
def get_missing_proportion(df):
    return pd.DataFrame({
    "missing_count":df.isnull().sum(),
    "missing_percent": (df.isnull().sum() / len(df)) * 100
}).sort_values(by = "missing_count", ascending= False)

# %%
def calculate_moving_average(df, columns,frequency : int = 7):
    '''
        Parameters:
            df, columns -> dataframe and columns you want to take moving average of
            frequency --> e.g.  7 day moving average or 28 day moving average
        
        returns
            df with the newly established Moving Average Columns
    '''
    df_v2 = df.copy()
    for column in columns:
        moving_average_column_name = f'{column}_MA_{frequency}'
        df_v2[moving_average_column_name] = df_v2[column].rolling(window = frequency).mean()

    return df_v2

# %%
df = pd.read_csv("./cleaned_data/p07.csv", index_col="dateTime")
df.index = pd.to_datetime(df.index)
core_features = ["avg_daily_heart_rate",
                 "steps_sum",
                "very_active_minutes_sum",
               "moderately_active_minutes_sum",
                "sedentary_minutes_sum",
                "lightly_active_minutes_sum",
                "avg_overall_sleep_score",
                "total_rem_sleep_minutes",
                "total_deep_sleep_minutes",
                "avg_restlessness",
                "soreness",
                "sleep_quality"
       ]
sleep_features = ["sleep_quality", "total_deep_sleep_minutes","total_rem_sleep_minutes", "avg_overall_sleep_score"]
core_target = ["mood","stress","fatigue","readiness"]

# %%
draw_plots_grid(df, core_features,nrows = 3, ncols = 4)

# %%
draw_plots_grid(df, core_target,save_path="./figures/missing_data.png",nrows = 3, ncols = 4)

# %%
gap_analysis_results = {col:analyze_gaps(df,col) for col in df.columns}

gap_summary = pd.DataFrame.from_dict(gap_analysis_results, orient= "index")
missing_analysis = get_missing_proportion(df)
full_missing_analysis = pd.concat([missing_analysis, gap_summary], axis=1)
# full_missing_analysis.to_csv("cleaned_data/missing_analysis.csv")

# %%
plot_missing_values_heatmap(df, save_path="missing_values.png")

# %%
plot_missing_values_correlation(df,save_path="missing_values_corr.png")

# %%
full_missing_analysis
# Out:
#                                        missing_count  missing_percent  \
# has_injury_reported                              134        90.540541
# num_unique_injury_areas_daily                    134        90.540541
# unique_daily_activity_names                       45        30.405405
# total_daily_duration_min                          45        30.405405
# total_daily_training_load_srpe                    45        30.405405
# num_daily_srpe_sessions                           45        30.405405
# avg_daily_perceived_exertion                      45        30.405405
# had_evening                                       30        20.270270
# had_breakfast                                     30        20.270270
# had_dinner                                        30        20.270270
# total_glasses_of_fluid                            30        20.270270
# alcohol_consumed_daily_flag                       30        20.270270
# had_lunch                                         30        20.270270
# weight                                            30        20.270270
# total_exercise_calories                           24        16.216216
# total_exercise_distance_km                        24        16.216216
# total_exercise_steps                              24        16.216216
# num_exercise_sessions                             24        16.216216
# avg_exercise_heart_rate                           24        16.216216
# total_exercise_duration_minutes                   24        16.216216
# soreness                                          16        10.810811
# sleep_quality                                     16        10.810811
# stress                                            16        10.810811
# sleep_duration_h                                  16        10.810811
# fatigue                                           16        10.810811
# mood                                              16        10.810811
# readiness                                         16        10.810811
# avg_revitalization_score                           8         5.405405
# avg_composition_score                              8         5.405405
# avg_overall_sleep_score                            8         5.405405
# avg_duration_score                                 8         5.405405
# avg_restlessness                                   8         5.405405
# total_light_sleep_minutes                          6         4.054054
# total_deep_sleep_minutes                           6         4.054054
# total_time_in_bed_minutes                          6         4.054054
# total_sleep_duration_minutes                       6         4.054054
# total_minutes_asleep                               6         4.054054
# total_minutes_awake_during_sleep                   6         4.054054
# avg_sleep_efficiency                               6         4.054054
# avg_minutes_after_wakeup                           6         4.054054
# avg_minutes_to_fall_asleep                         6         4.054054
# total_awake_minutes_in_sleep_stages                6         4.054054
# total_rem_sleep_minutes                            6         4.054054
# time_in_below_default_zone1_minutes_x              1         0.675676
# time_in_fat_burn_zone_minutes_x                    1         0.675676
# time_in_cardio_zone_minutes_x                      1         0.675676
# time_in_peak_zone_minutes_x                        1         0.675676
# steps_sum                                          1         0.675676
# distance_sum                                       1         0.675676
# avg_daily_heart_rate                               1         0.675676
# sedentary_minutes_sum                              0         0.000000
# very_active_minutes_sum                            0         0.000000
# lightly_active_minutes_sum                         0         0.000000
# moderately_active_minutes_sum                      0         0.000000
#
#                                        num_gaps  max_gap_length  \
# has_injury_reported                          15              26
# num_unique_injury_areas_daily                15              26
# unique_daily_activity_names                  26               6
# total_daily_duration_min                     26               6
# total_daily_training_load_srpe               26               6
# num_daily_srpe_sessions                      26               6
# avg_daily_perceived_exertion                 26               6
# had_evening                                  10              10
# had_breakfast                                10              10
# had_dinner                                   10              10
# total_glasses_of_fluid                       10              10
# alcohol_consumed_daily_flag                  10              10
# had_lunch                                    10              10
# weight                                       10              10
# total_exercise_calories                      19               3
# total_exercise_distance_km                   19               3
# total_exercise_steps                         19               3
# num_exercise_sessions                        19               3
# avg_exercise_heart_rate                      19               3
# total_exercise_duration_minutes              19               3
# soreness                                     11               4
# sleep_quality                                11               4
# stress                                       11               4
# sleep_duration_h                             11               4
# fatigue                                      11               4
# mood                                         11               4
# readiness                                    11               4
# avg_revitalization_score                      6               3
# avg_composition_score                         6               3
# avg_overall_sleep_score                       6               3
# avg_duration_score                            6               3
# avg_restlessness                              6               3
# total_light_sleep_minutes                     5               2
# total_deep_sleep_minutes                      5               2
# total_time_in_bed_minutes                     5               2
# total_sleep_duration_minutes                  5               2
# total_minutes_asleep                          5               2
# total_minutes_awake_during_sleep              5               2
# avg_sleep_efficiency                          5               2
# avg_minutes_after_wakeup                      5               2
# avg_minutes_to_fall_asleep                    5               2
# total_awake_minutes_in_sleep_stages           5               2
# total_rem_sleep_minutes                       5               2
# time_in_below_default_zone1_minutes_x         1               1
# time_in_fat_burn_zone_minutes_x               1               1
# time_in_cardio_zone_minutes_x                 1               1
# time_in_peak_zone_minutes_x                   1               1
# steps_sum                                     1               1
# distance_sum                                  1               1
# avg_daily_heart_rate                          1               1
# sedentary_minutes_sum                         0               0
# very_active_minutes_sum                       0               0
# lightly_active_minutes_sum                    0               0
# moderately_active_minutes_sum                 0               0
#
#                                        avg_gap_length
# has_injury_reported                          8.933333
# num_unique_injury_areas_daily                8.933333
# unique_daily_activity_names                  1.730769
# total_daily_duration_min                     1.730769
# total_daily_training_load_srpe               1.730769
# num_daily_srpe_sessions                      1.730769
# avg_daily_perceived_exertion                 1.730769
# had_evening                                  3.000000
# had_breakfast                                3.000000
# had_dinner                                   3.000000
# total_glasses_of_fluid                       3.000000
# alcohol_consumed_daily_flag                  3.000000
# had_lunch                                    3.000000
# weight                                       3.000000
# total_exercise_calories                      1.263158
# total_exercise_distance_km                   1.263158
# total_exercise_steps                         1.263158
# num_exercise_sessions                        1.263158
# avg_exercise_heart_rate                      1.263158
# total_exercise_duration_minutes              1.263158
# soreness                                     1.454545
# sleep_quality                                1.454545
# stress                                       1.454545
# sleep_duration_h                             1.454545
# fatigue                                      1.454545
# mood                                         1.454545
# readiness                                    1.454545
# avg_revitalization_score                     1.333333
# avg_composition_score                        1.333333
# avg_overall_sleep_score                      1.333333
# avg_duration_score                           1.333333
# avg_restlessness                             1.333333
# total_light_sleep_minutes                    1.200000
# total_deep_sleep_minutes                     1.200000
# total_time_in_bed_minutes                    1.200000
# total_sleep_duration_minutes                 1.200000
# total_minutes_asleep                         1.200000
# total_minutes_awake_during_sleep             1.200000
# avg_sleep_efficiency                         1.200000
# avg_minutes_after_wakeup                     1.200000
# avg_minutes_to_fall_asleep                   1.200000
# total_awake_minutes_in_sleep_stages          1.200000
# total_rem_sleep_minutes                      1.200000
# time_in_below_default_zone1_minutes_x        1.000000
# time_in_fat_burn_zone_minutes_x              1.000000
# time_in_cardio_zone_minutes_x                1.000000
# time_in_peak_zone_minutes_x                  1.000000
# steps_sum                                    1.000000
# distance_sum                                 1.000000
# avg_daily_heart_rate                         1.000000
# sedentary_minutes_sum                        0.000000
# very_active_minutes_sum                      0.000000
# lightly_active_minutes_sum                   0.000000
# moderately_active_minutes_sum                0.000000

# %%
df.drop(["num_unique_injury_areas_daily","has_injury_reported"], axis = 1, inplace = True)

# %% [raw]
# # Sleep Data Block
# sleep_data_columns = [
#     'total_sleep_duration_minutes',
#     'total_minutes_asleep',
#     'total_minutes_awake_during_sleep',
#     'total_time_in_bed_minutes',
#     'total_deep_sleep_minutes',
#     'total_light_sleep_minutes',
#     'total_rem_sleep_minutes',
#     'total_awake_minutes_in_sleep_stages',
#     'avg_minutes_to_fall_asleep',
#     'avg_minutes_after_wakeup',
#     'avg_sleep_efficiency',
#     'avg_overall_sleep_score',
#     'avg_composition_score',
#     'avg_revitalization_score',
#     'avg_duration_score',
#     'avg_restlessness'
# ]
#
# # Logged Exercise Block
# exercise_data_columns = [
#     'total_exercise_calories',
#     'total_exercise_duration_minutes',
#     'total_exercise_steps',
#     'total_exercise_distance_km',
#     'avg_exercise_heart_rate',
#     'num_exercise_sessions',
#     'steps_sum',
#     'very_active_minutes_sum',
#     'moderately_active_minutes_sum',
#     'lightly_active_minutes_sum',
#     'sedentary_minutes_sum',
#     'distance_sum',
#     'time_in_below_default_zone1_minutes_x',
#     'time_in_fat_burn_zone_minutes_x',
#     'time_in_cardio_zone_minutes_x',
#     'time_in_peak_zone_minutes_x'
# ]
#
# # sRPE Block
# srpe_columns = [
#     'total_daily_training_load_srpe',
#     'total_daily_duration_min',
#     'avg_daily_perceived_exertion',
#     'num_daily_srpe_sessions'
# ]
#
# # Self-Report & Lifestyle Block
#
# ## Lifestyle Factors
# lifestyle_factors_columns = [
#     'weight',
#     'total_glasses_of_fluid',
#     'alcohol_consumed_daily_flag',
#     'had_breakfast',
#     'had_lunch',
#     'had_dinner',
#     'had_evening',
#     'has_injury_reported',
#     'num_unique_injury_areas_daily',
#     'avg_daily_heart_rate'
# ]
#
# ## Core Targets
# core_targets_columns = [
#     'fatigue',
#     'mood',
#     'readiness',
#     'soreness',
#     'stress'
# ]

# %%
sleep_data_columns = ["avg_overall_sleep_score",
                      "total_minutes_asleep",
                     "total_rem_sleep_minutes",
                     "total_deep_sleep_minutes",
                     "avg_restlessness"]

exercise_data_columns = [
    "total_exercise_duration_minutes",
    "avg_exercise_heart_rate",
    "num_exercise_sessions",    
]

physiological_signals_columns = [
    "avg_daily_heart_rate",
    "sedentary_minutes_sum",
    "lightly_active_minutes_sum",
    "very_active_minutes_sum",
    'time_in_below_default_zone1_minutes_x',
    'time_in_fat_burn_zone_minutes_x',
    'time_in_cardio_zone_minutes_x',
    'time_in_peak_zone_minutes_x'
]

srpe_columns = [
    "total_daily_training_load_srpe"
]

lifestyle_columns = [
    "alcohol_consumed_daily_flag",
    "weight",
    'had_breakfast',
    'had_lunch',
    'had_dinner',
    'had_evening',
    ]

core_targets_columns = [
    'fatigue',
    'mood',
    'readiness',
    'soreness',
    'stress'
]

all_columns = sleep_data_columns + exercise_data_columns + physiological_signals_columns + srpe_columns + lifestyle_columns + core_targets_columns

# %%
df[all_columns].isna().sum()
# Out:
# avg_overall_sleep_score                   8
# total_minutes_asleep                      6
# total_rem_sleep_minutes                   6
# total_deep_sleep_minutes                  6
# avg_restlessness                          8
# total_exercise_duration_minutes          24
# avg_exercise_heart_rate                  24
# num_exercise_sessions                    24
# avg_daily_heart_rate                      1
# sedentary_minutes_sum                     0
# lightly_active_minutes_sum                0
# very_active_minutes_sum                   0
# time_in_below_default_zone1_minutes_x     1
# time_in_fat_burn_zone_minutes_x           1
# time_in_cardio_zone_minutes_x             1
# time_in_peak_zone_minutes_x               1
# total_daily_training_load_srpe           45
# alcohol_consumed_daily_flag              30
# weight                                   30
# had_breakfast                            30
# had_lunch                                30
# had_dinner                               30
# had_evening                              30
# fatigue                                  16
# mood                                     16
# readiness                                16
# soreness                                 16
# stress                                   16
# dtype: int64

# %% [markdown]
# # Missing Values

# %% [markdown]
# **Sleep Block**
# The gaps are few and relatively short (max gap of 3 days). The best method here is time-based interpolation. This will create a smooth, plausible continuous signal, which is essential for calculating clean moving averages and for use in daily models. This directly fixes the broken plots you encountered earlier.
#
# Action: Apply .interpolate(method='time') to all columns in the sleep data block.

# %%
df[sleep_data_columns] = df[sleep_data_columns].interpolate(method = "time")

# %% [markdown]
# **Logged Exercise Block**
# The missingness in these columns does not mean "unknown"; it means "an exercise/session was not logged". Imputing with a mean or median would be logically wrong, as it would invent exercise on rest days. The correct representation is zero.
#
# Action: Fill all NaN values in these two blocks with 0. This correctly transforms the data to represent "0 minutes of logged exercise" or a "daily training load of 0".

# %%
df[exercise_data_columns] = df[exercise_data_columns].fillna(0)

# %%
df[srpe_columns] = df[srpe_columns].fillna(0)

# %% [markdown]
# **Self-Report & Lifestyle Block**
# 1) Core Targets (mood, stress, fatigue, readiness, soreness):
#    As established, this is likely MNAR data. Do not impute these columns. They represent your ground truth and should remain unaltered. Your models will be trained only on the days these values are present.
#
# 2) Lifestyle Factors (weight, total_glasses_of_fluid, had_breakfast, etc.):
#     Since these are part of the same "daily journal event" and will be used as predictor features, filling them with 0 for binary flags (alcohol_consumed_daily_flag) or applying a forward-fill (ffill) for values like weight is a reasonable approach for now. This assumes that if a user did not log these, the event did not occur or the value was stable. This is a pragmatic choice to prepare the data for modeling, but the underlying assumption should be noted.

# %%
df[lifestyle_columns].isna().sum()
# Out:
# alcohol_consumed_daily_flag    30
# weight                         30
# had_breakfast                  30
# had_lunch                      30
# had_dinner                     30
# had_evening                    30
# dtype: int64

# %%
df["weight"] = df["weight"].ffill()

# %%
df["alcohol_consumed_daily_flag"] = df["alcohol_consumed_daily_flag"].fillna(0)

# %%
def fill_with_zero(df):
    return df.fillna(0)

# %%
df["had_lunch"] = df["had_lunch"].fillna(0)
print(df["had_dinner"].value_counts())
print(df["had_evening"].value_counts())
print(df["had_breakfast"].value_counts())
print(df["weight"].value_counts())
# Out:
# had_dinner
# 1.0    109
# 0.0      9
# Name: count, dtype: int64
# had_evening
# 1.0    59
# 0.0    59
# Name: count, dtype: int64
# had_breakfast
# 1.0    74
# 0.0    44
# Name: count, dtype: int64
# weight
# 66.0    54
# 67.0    51
# 68.0    39
# Name: count, dtype: int64

# %%
df[["had_lunch","had_dinner","had_breakfast","had_evening"]] = df[["had_lunch","had_dinner","had_breakfast","had_evening"]].apply(fill_with_zero)

# %%
df = df.drop(df.drop(all_columns, axis = 1).columns, axis = 1)

# %% [markdown]
# **Physiological Data**

# %%
df[physiological_signals_columns].isna().sum()
# Out:
# avg_daily_heart_rate                     1
# sedentary_minutes_sum                    0
# lightly_active_minutes_sum               0
# very_active_minutes_sum                  0
# time_in_below_default_zone1_minutes_x    1
# time_in_fat_burn_zone_minutes_x          1
# time_in_cardio_zone_minutes_x            1
# time_in_peak_zone_minutes_x              1
# dtype: int64

# %%
df.dropna(subset=['avg_overall_sleep_score', 'weight'], inplace=True)

# %%
df.shape
# Out:
# (144, 28)

# %% [markdown]
# Step 2: Engineer Features to Capture Dynamics and Relationships
# Raw daily data is noisy. The real insights come from features that describe trends, changes, and relationships over time.
#
# Recalculate Moving Averages: Now that the sleep data is continuous, recalculate your 7-day and 28-day moving averages for sleep, heart rate, and activity metrics. These will now be complete and serve as reliable indicators of short-term and long-term trends.
#
# Engineer "Delta" and "Deviation" Features: The most powerful signals are often not the absolute values, but the changes relative to a baseline.
#
# Action: Create features like heart_rate_deviation_from_28day_avg (i.e., daily_hr - hr_28_day_avg) or sleep_score_change_from_yesterday. These features are excellent for identifying anomalies and flagging days that are physiologically unusual for the individual.
# Engineer Lagged Features for Predictive Modeling: To model the effect of one day's events on the next day's mood, you must create lagged features.
#
# Action: Create columns like sleep_score_lag1, active_minutes_lag1, and alcohol_consumed_lag1. These represent yesterday's values and will be the primary predictors for today's mood or stress.

# %%
df[all_columns].head()
# Out:
#             avg_overall_sleep_score  total_minutes_asleep  \
# dateTime
# 2019-11-09                     76.0                 421.0
# 2019-11-10                     81.0                 438.5
# 2019-11-11                     86.0                 456.0
# 2019-11-12                     78.0                 452.0
# 2019-11-13                     76.0                 443.0
#
#             total_rem_sleep_minutes  total_deep_sleep_minutes  \
# dateTime
# 2019-11-09                     39.0                      74.0
# 2019-11-10                     88.5                      85.5
# 2019-11-11                    138.0                      97.0
# 2019-11-12                     82.0                      95.0
# 2019-11-13                     63.0                      71.0
#
#             avg_restlessness  total_exercise_duration_minutes  \
# dateTime
# 2019-11-09          0.052500                       17600000.0
# 2019-11-10          0.047474                              0.0
# 2019-11-11          0.042448                        4652000.0
# 2019-11-12          0.054081                              0.0
# 2019-11-13          0.062681                        3431000.0
#
#             avg_exercise_heart_rate  num_exercise_sessions  \
# dateTime
# 2019-11-09                    140.5                    2.0
# 2019-11-10                      0.0                    0.0
# 2019-11-11                    135.5                    2.0
# 2019-11-12                      0.0                    0.0
# 2019-11-13                    148.0                    1.0
#
#             avg_daily_heart_rate  sedentary_minutes_sum  ...  weight  \
# dateTime                                                 ...
# 2019-11-09            109.914619                    383  ...    68.0
# 2019-11-10             63.086870                   1240  ...    68.0
# 2019-11-11             75.222814                    637  ...    68.0
# 2019-11-12             59.924589                    709  ...    68.0
# 2019-11-13             73.750455                    600  ...    68.0
#
#             had_breakfast  had_lunch  had_dinner  had_evening  fatigue  mood  \
# dateTime
# 2019-11-09            1.0        1.0         1.0          1.0      4.0   4.0
# 2019-11-10            0.0        0.0         0.0          0.0      3.0   3.0
# 2019-11-11            1.0        1.0         1.0          1.0      2.0   3.0
# 2019-11-12            1.0        1.0         1.0          1.0      3.0   3.0
# 2019-11-13            1.0        1.0         1.0          1.0      2.0   3.0
#
#             readiness  soreness  stress
# dateTime
# 2019-11-09        8.0       3.0     4.0
# 2019-11-10        4.0       2.0     4.0
# 2019-11-11        2.0       3.0     5.0
# 2019-11-12        6.0       3.0     4.0
# 2019-11-13        4.0       3.0     2.0
#
# [5 rows x 28 columns]

# %%
draw_plots_grid(df, physiological_signals_columns + sleep_data_columns,windows=[7, 28],nrows = 5, ncols = 4, save_path="./figures/cleaned_distribution.png")

# %%
df[all_columns].isna().sum()
# Out:
# avg_overall_sleep_score                   0
# total_minutes_asleep                      0
# total_rem_sleep_minutes                   0
# total_deep_sleep_minutes                  0
# avg_restlessness                          0
# total_exercise_duration_minutes           0
# avg_exercise_heart_rate                   0
# num_exercise_sessions                     0
# avg_daily_heart_rate                      0
# sedentary_minutes_sum                     0
# lightly_active_minutes_sum                0
# very_active_minutes_sum                   0
# time_in_below_default_zone1_minutes_x     0
# time_in_fat_burn_zone_minutes_x           0
# time_in_cardio_zone_minutes_x             0
# time_in_peak_zone_minutes_x               0
# total_daily_training_load_srpe            0
# alcohol_consumed_daily_flag               0
# weight                                    0
# had_breakfast                             0
# had_lunch                                 0
# had_dinner                                0
# had_evening                               0
# fatigue                                  15
# mood                                     15
# readiness                                15
# soreness                                 15
# stress                                   15
# dtype: int64

# %% [markdown]
# ## Feature Engineering Moving Averages

# %%
columns_to_exclude = {
    "alcohol_consumed_daily_flag",
    "weight",
    'had_breakfast',
    'had_lunch',
    'had_dinner',
    'had_evening',
    'fatigue',
    'mood',
    'stress',
    'soreness',
    'readiness'
}

moving_average_columns = [column for column in all_columns if column not in columns_to_exclude]

# %%
moving_average_columns
# Out:
# ['avg_overall_sleep_score',
#  'total_minutes_asleep',
#  'total_rem_sleep_minutes',
#  'total_deep_sleep_minutes',
#  'avg_restlessness',
#  'total_exercise_duration_minutes',
#  'avg_exercise_heart_rate',
#  'num_exercise_sessions',
#  'avg_daily_heart_rate',
#  'sedentary_minutes_sum',
#  'lightly_active_minutes_sum',
#  'very_active_minutes_sum',
#  'time_in_below_default_zone1_minutes_x',
#  'time_in_fat_burn_zone_minutes_x',
#  'time_in_cardio_zone_minutes_x',
#  'time_in_peak_zone_minutes_x',
#  'total_daily_training_load_srpe']

# %%
df = calculate_moving_average(df, moving_average_columns,7)

# %%
df = calculate_moving_average(df, moving_average_columns,30)

# %%
print(df.columns.tolist())
# Out:
# ['fatigue', 'mood', 'readiness', 'soreness', 'stress', 'weight', 'alcohol_consumed_daily_flag', 'had_breakfast', 'had_lunch', 'had_dinner', 'had_evening', 'total_daily_training_load_srpe', 'total_exercise_duration_minutes', 'avg_exercise_heart_rate', 'num_exercise_sessions', 'total_minutes_asleep', 'total_deep_sleep_minutes', 'total_rem_sleep_minutes', 'avg_overall_sleep_score', 'avg_restlessness', 'time_in_below_default_zone1_minutes_x', 'time_in_fat_burn_zone_minutes_x', 'time_in_cardio_zone_minutes_x', 'time_in_peak_zone_minutes_x', 'very_active_minutes_sum', 'sedentary_minutes_sum', 'lightly_active_minutes_sum', 'avg_daily_heart_rate', 'avg_overall_sleep_score_MA_7', 'total_minutes_asleep_MA_7', 'total_rem_sleep_minutes_MA_7', 'total_deep_sleep_minutes_MA_7', 'avg_restlessness_MA_7', 'total_exercise_duration_minutes_MA_7', 'avg_exercise_heart_rate_MA_7', 'num_exercise_sessions_MA_7', 'avg_daily_heart_rate_MA_7', 'sedentary_minutes_sum_MA_7', 'lightly_active_minutes_sum_MA_7', 'very_active_minutes_sum_MA_7', 'time_in_below_default_zone1_minutes_x_MA_7', 'time_in_fat_burn_zone_minutes_x_MA_7', 'time_in_cardio_zone_minutes_x_MA_7', 'time_in_peak_zone_minutes_x_MA_7', 'total_daily_training_load_srpe_MA_7', 'avg_overall_sleep_score_MA_30', 'total_minutes_asleep_MA_30', 'total_rem_sleep_minutes_MA_30', 'total_deep_sleep_minutes_MA_30', 'avg_restlessness_MA_30', 'total_exercise_duration_minutes_MA_30', 'avg_exercise_heart_rate_MA_30', 'num_exercise_sessions_MA_30', 'avg_daily_heart_rate_MA_30', 'sedentary_minutes_sum_MA_30', 'lightly_active_minutes_sum_MA_30', 'very_active_minutes_sum_MA_30', 'time_in_below_default_zone1_minutes_x_MA_30', 'time_in_fat_burn_zone_minutes_x_MA_30', 'time_in_cardio_zone_minutes_x_MA_30', 'time_in_peak_zone_minutes_x_MA_30', 'total_daily_training_load_srpe_MA_30']

# %% [markdown]
# ## Deviation and Delta Features

# %%
def calculate_delta_features(df, columns):
    df = df.copy()
    
    for column in columns:
        if column in df.columns:
            column_name = f"{column}_delta_day_over_day"
            df[column_name] = df[column].diff(1)
    return df

def calculate_deviation_features(df, columns):
    df = df.copy()
    moving_average_windows = ['MA_7', 'MA_30']
    for column in columns:
        for window in moving_average_windows:
            ma_column_name = f"{column}_{window}"
            if ma_column_name in df.columns and column in df.columns:
                df[f'{column}_deviation_{window}'] = df[column] - df[ma_column_name]


    return df

def calculate_lagged_features(df,columns,N):
    df = df.copy()
    for column in columns:
        if column in df.columns:
            df[f"{column}_lag{N}"] = df[column].shift(N)

    return df

# %%
df = calculate_delta_features(df, moving_average_columns)

# %%
df = calculate_deviation_features(df, moving_average_columns)

# %%
print(df.columns.tolist())
# Out:
# ['fatigue', 'mood', 'readiness', 'soreness', 'stress', 'weight', 'alcohol_consumed_daily_flag', 'had_breakfast', 'had_lunch', 'had_dinner', 'had_evening', 'total_daily_training_load_srpe', 'total_exercise_duration_minutes', 'avg_exercise_heart_rate', 'num_exercise_sessions', 'total_minutes_asleep', 'total_deep_sleep_minutes', 'total_rem_sleep_minutes', 'avg_overall_sleep_score', 'avg_restlessness', 'time_in_below_default_zone1_minutes_x', 'time_in_fat_burn_zone_minutes_x', 'time_in_cardio_zone_minutes_x', 'time_in_peak_zone_minutes_x', 'very_active_minutes_sum', 'sedentary_minutes_sum', 'lightly_active_minutes_sum', 'avg_daily_heart_rate', 'avg_overall_sleep_score_MA_7', 'total_minutes_asleep_MA_7', 'total_rem_sleep_minutes_MA_7', 'total_deep_sleep_minutes_MA_7', 'avg_restlessness_MA_7', 'total_exercise_duration_minutes_MA_7', 'avg_exercise_heart_rate_MA_7', 'num_exercise_sessions_MA_7', 'avg_daily_heart_rate_MA_7', 'sedentary_minutes_sum_MA_7', 'lightly_active_minutes_sum_MA_7', 'very_active_minutes_sum_MA_7', 'time_in_below_default_zone1_minutes_x_MA_7', 'time_in_fat_burn_zone_minutes_x_MA_7', 'time_in_cardio_zone_minutes_x_MA_7', 'time_in_peak_zone_minutes_x_MA_7', 'total_daily_training_load_srpe_MA_7', 'avg_overall_sleep_score_MA_30', 'total_minutes_asleep_MA_30', 'total_rem_sleep_minutes_MA_30', 'total_deep_sleep_minutes_MA_30', 'avg_restlessness_MA_30', 'total_exercise_duration_minutes_MA_30', 'avg_exercise_heart_rate_MA_30', 'num_exercise_sessions_MA_30', 'avg_daily_heart_rate_MA_30', 'sedentary_minutes_sum_MA_30', 'lightly_active_minutes_sum_MA_30', 'very_active_minutes_sum_MA_30', 'time_in_below_default_zone1_minutes_x_MA_30', 'time_in_fat_burn_zone_minutes_x_MA_30', 'time_in_cardio_zone_minutes_x_MA_30', 'time_in_peak_zone_minutes_x_MA_30', 'total_daily_training_load_srpe_MA_30', 'avg_overall_sleep_score_delta_day_over_day', 'total_minutes_asleep_delta_day_over_day', 'total_rem_sleep_minutes_delta_day_over_day', 'total_deep_sleep_minutes_delta_day_over_day', 'avg_restlessness_delta_day_over_day', 'total_exercise_duration_minutes_delta_day_over_day', 'avg_exercise_heart_rate_delta_day_over_day', 'num_exercise_sessions_delta_day_over_day', 'avg_daily_heart_rate_delta_day_over_day', 'sedentary_minutes_sum_delta_day_over_day', 'lightly_active_minutes_sum_delta_day_over_day', 'very_active_minutes_sum_delta_day_over_day', 'time_in_below_default_zone1_minutes_x_delta_day_over_day', 'time_in_fat_burn_zone_minutes_x_delta_day_over_day', 'time_in_cardio_zone_minutes_x_delta_day_over_day', 'time_in_peak_zone_minutes_x_delta_day_over_day', 'total_daily_training_load_srpe_delta_day_over_day', 'avg_overall_sleep_score_deviation_MA_7', 'avg_overall_sleep_score_deviation_MA_30', 'total_minutes_asleep_deviation_MA_7', 'total_minutes_asleep_deviation_MA_30', 'total_rem_sleep_minutes_deviation_MA_7', 'total_rem_sleep_minutes_deviation_MA_30', 'total_deep_sleep_minutes_deviation_MA_7', 'total_deep_sleep_minutes_deviation_MA_30', 'avg_restlessness_deviation_MA_7', 'avg_restlessness_deviation_MA_30', 'total_exercise_duration_minutes_deviation_MA_7', 'total_exercise_duration_minutes_deviation_MA_30', 'avg_exercise_heart_rate_deviation_MA_7', 'avg_exercise_heart_rate_deviation_MA_30', 'num_exercise_sessions_deviation_MA_7', 'num_exercise_sessions_deviation_MA_30', 'avg_daily_heart_rate_deviation_MA_7', 'avg_daily_heart_rate_deviation_MA_30', 'sedentary_minutes_sum_deviation_MA_7', 'sedentary_minutes_sum_deviation_MA_30', 'lightly_active_minutes_sum_deviation_MA_7', 'lightly_active_minutes_sum_deviation_MA_30', 'very_active_minutes_sum_deviation_MA_7', 'very_active_minutes_sum_deviation_MA_30', 'time_in_below_default_zone1_minutes_x_deviation_MA_7', 'time_in_below_default_zone1_minutes_x_deviation_MA_30', 'time_in_fat_burn_zone_minutes_x_deviation_MA_7', 'time_in_fat_burn_zone_minutes_x_deviation_MA_30', 'time_in_cardio_zone_minutes_x_deviation_MA_7', 'time_in_cardio_zone_minutes_x_deviation_MA_30', 'time_in_peak_zone_minutes_x_deviation_MA_ ...

# %%
'fatigue_delta_day_over_day' in df.columns.tolist()
# Out:
# False

# %%
df.shape
# Out:
# (144, 113)

# %%
print(df.isna().sum().to_dict())
# Out:
# {'fatigue': 15, 'mood': 15, 'readiness': 15, 'soreness': 15, 'stress': 15, 'weight': 0, 'alcohol_consumed_daily_flag': 0, 'had_breakfast': 0, 'had_lunch': 0, 'had_dinner': 0, 'had_evening': 0, 'total_daily_training_load_srpe': 0, 'total_exercise_duration_minutes': 0, 'avg_exercise_heart_rate': 0, 'num_exercise_sessions': 0, 'total_minutes_asleep': 0, 'total_deep_sleep_minutes': 0, 'total_rem_sleep_minutes': 0, 'avg_overall_sleep_score': 0, 'avg_restlessness': 0, 'time_in_below_default_zone1_minutes_x': 0, 'time_in_fat_burn_zone_minutes_x': 0, 'time_in_cardio_zone_minutes_x': 0, 'time_in_peak_zone_minutes_x': 0, 'very_active_minutes_sum': 0, 'sedentary_minutes_sum': 0, 'lightly_active_minutes_sum': 0, 'avg_daily_heart_rate': 0, 'avg_overall_sleep_score_MA_7': 6, 'total_minutes_asleep_MA_7': 6, 'total_rem_sleep_minutes_MA_7': 6, 'total_deep_sleep_minutes_MA_7': 6, 'avg_restlessness_MA_7': 6, 'total_exercise_duration_minutes_MA_7': 6, 'avg_exercise_heart_rate_MA_7': 6, 'num_exercise_sessions_MA_7': 6, 'avg_daily_heart_rate_MA_7': 6, 'sedentary_minutes_sum_MA_7': 6, 'lightly_active_minutes_sum_MA_7': 6, 'very_active_minutes_sum_MA_7': 6, 'time_in_below_default_zone1_minutes_x_MA_7': 6, 'time_in_fat_burn_zone_minutes_x_MA_7': 6, 'time_in_cardio_zone_minutes_x_MA_7': 6, 'time_in_peak_zone_minutes_x_MA_7': 6, 'total_daily_training_load_srpe_MA_7': 6, 'avg_overall_sleep_score_MA_30': 29, 'total_minutes_asleep_MA_30': 29, 'total_rem_sleep_minutes_MA_30': 29, 'total_deep_sleep_minutes_MA_30': 29, 'avg_restlessness_MA_30': 29, 'total_exercise_duration_minutes_MA_30': 29, 'avg_exercise_heart_rate_MA_30': 29, 'num_exercise_sessions_MA_30': 29, 'avg_daily_heart_rate_MA_30': 29, 'sedentary_minutes_sum_MA_30': 29, 'lightly_active_minutes_sum_MA_30': 29, 'very_active_minutes_sum_MA_30': 29, 'time_in_below_default_zone1_minutes_x_MA_30': 29, 'time_in_fat_burn_zone_minutes_x_MA_30': 29, 'time_in_cardio_zone_minutes_x_MA_30': 29, 'time_in_peak_zone_minutes_x_MA_30': 29, 'total_daily_training_load_srpe_MA_30': 29, 'avg_overall_sleep_score_delta_day_over_day': 1, 'total_minutes_asleep_delta_day_over_day': 1, 'total_rem_sleep_minutes_delta_day_over_day': 1, 'total_deep_sleep_minutes_delta_day_over_day': 1, 'avg_restlessness_delta_day_over_day': 1, 'total_exercise_duration_minutes_delta_day_over_day': 1, 'avg_exercise_heart_rate_delta_day_over_day': 1, 'num_exercise_sessions_delta_day_over_day': 1, 'avg_daily_heart_rate_delta_day_over_day': 1, 'sedentary_minutes_sum_delta_day_over_day': 1, 'lightly_active_minutes_sum_delta_day_over_day': 1, 'very_active_minutes_sum_delta_day_over_day': 1, 'time_in_below_default_zone1_minutes_x_delta_day_over_day': 1, 'time_in_fat_burn_zone_minutes_x_delta_day_over_day': 1, 'time_in_cardio_zone_minutes_x_delta_day_over_day': 1, 'time_in_peak_zone_minutes_x_delta_day_over_day': 1, 'total_daily_training_load_srpe_delta_day_over_day': 1, 'avg_overall_sleep_score_deviation_MA_7': 6, 'avg_overall_sleep_score_deviation_MA_30': 29, 'total_minutes_asleep_deviation_MA_7': 6, 'total_minutes_asleep_deviation_MA_30': 29, 'total_rem_sleep_minutes_deviation_MA_7': 6, 'total_rem_sleep_minutes_deviation_MA_30': 29, 'total_deep_sleep_minutes_deviation_MA_7': 6, 'total_deep_sleep_minutes_deviation_MA_30': 29, 'avg_restlessness_deviation_MA_7': 6, 'avg_restlessness_deviation_MA_30': 29, 'total_exercise_duration_minutes_deviation_MA_7': 6, 'total_exercise_duration_minutes_deviation_MA_30': 29, 'avg_exercise_heart_rate_deviation_MA_7': 6, 'avg_exercise_heart_rate_deviation_MA_30': 29, 'num_exercise_sessions_deviation_MA_7': 6, 'num_exercise_sessions_deviation_MA_30': 29, 'avg_daily_heart_rate_deviation_MA_7': 6, 'avg_daily_heart_rate_deviation_MA_30': 29, 'sedentary_minutes_sum_deviation_MA_7': 6, 'sedentary_minutes_sum_deviation_MA_30': 29, 'lightly_active_minutes_sum_deviation_MA_7': 6, 'lightly_active_minutes_sum_deviation_MA_30': 29, 'very_active_minutes_sum_deviation_MA_7': 6, 'very_active_minutes_sum_deviation_MA_30': 29, 'time_in_b ...

# %% [markdown]
# ## lagging

# %%
features_to_lag = [
    # Core Subjective Metrics (highly influential and often targets)
    'fatigue',
    'mood',
    'readiness',
    'soreness',
    'stress',

    # Key Physiological & Activity Metrics (direct influences on next-day well-being)
    'total_minutes_asleep',
    'total_deep_sleep_minutes',
    'total_rem_sleep_minutes',
    'avg_overall_sleep_score',
    'avg_restlessness',
    'avg_daily_heart_rate',
    'total_exercise_duration_minutes',
    'avg_exercise_heart_rate',
    'num_exercise_sessions',
    'sedentary_minutes_sum',
    'lightly_active_minutes_sum',
    'very_active_minutes_sum',
    'time_in_below_default_zone1_minutes_x', # Assuming this is your consolidated HR zone column
    'time_in_fat_burn_zone_minutes_x',
    'time_in_cardio_zone_minutes_x',
    'time_in_peak_zone_minutes_x',
    'total_daily_training_load_srpe',

    # Lifestyle Metrics (contextual influences)
    'weight',
    #'total_glasses_of_fluid',
    'alcohol_consumed_daily_flag',
    'had_breakfast',
    'had_lunch',
    'had_dinner',
    'had_evening',

    # Selected Delta Features (capture immediate change dynamics)
    #'fatigue_delta_day_over_day',
    #'mood_delta_day_over_day',
    #'readiness_delta_day_over_day',
    #'stress_delta_day_over_day',
    'avg_overall_sleep_score_delta_day_over_day',
    'avg_daily_heart_rate_delta_day_over_day',
    'total_exercise_duration_minutes_delta_day_over_day',
    'total_daily_training_load_srpe_delta_day_over_day',

    # Selected Deviation Features (capture unusualness relative to baseline)
    #'fatigue_deviation_MA_7', # or MA_30, choose based on perceived impact
    #'mood_deviation_MA_7',
    #'readiness_deviation_MA_7',
    #'stress_deviation_MA_7',
    'avg_overall_sleep_score_deviation_MA_7',
    'avg_daily_heart_rate_deviation_MA_7',
    'total_exercise_duration_minutes_deviation_MA_7',
    'total_daily_training_load_srpe_deviation_MA_7'
]

features_not_to_lag = [
    # Moving Averages (already smoothed temporal representations)
    'avg_overall_sleep_score_MA_7',
    'total_minutes_asleep_MA_7',
    'total_rem_sleep_minutes_MA_7',
    'total_deep_sleep_minutes_MA_7',
    'avg_restlessness_MA_7',
    'total_exercise_duration_minutes_MA_7',
    'avg_exercise_heart_rate_MA_7',
    'num_exercise_sessions_MA_7', # MA of counts can be useful for dashboards, but less for lagging as predictors
    'avg_daily_heart_rate_MA_7',
    'sedentary_minutes_sum_MA_7',
    'lightly_active_minutes_sum_MA_7',
    'very_active_minutes_sum_MA_7',
    'time_in_below_default_zone1_minutes_x_MA_7',
    'time_in_fat_burn_zone_minutes_x_MA_7',
    'time_in_cardio_zone_minutes_x_MA_7',
    'time_in_peak_zone_minutes_x_MA_7',
    'total_daily_training_load_srpe_MA_7',

    'avg_overall_sleep_score_MA_30',
    'total_minutes_asleep_MA_30',
    'total_rem_sleep_minutes_MA_30',
    'total_deep_sleep_minutes_MA_30',
    'avg_restlessness_MA_30',
    'total_exercise_duration_minutes_MA_30',
    'avg_exercise_heart_rate_MA_30',
    'num_exercise_sessions_MA_30',
    'avg_daily_heart_rate_MA_30',
    'sedentary_minutes_sum_MA_30',
    'lightly_active_minutes_sum_MA_30',
    'very_active_minutes_sum_MA_30',
    'time_in_below_default_zone1_minutes_x_MA_30',
    'time_in_fat_burn_zone_minutes_x_MA_30',
    'time_in_cardio_zone_minutes_x_MA_30',
    'time_in_peak_zone_minutes_x_MA_30',
    'total_daily_training_load_srpe_MA_30',

    # Other raw metrics that are already covered by more specific lagged features,
    # or are highly correlated with other lagged features
    'steps_sum', # Often correlated with exercise duration/distance. Could be lagged but prioritizing others.
    'distance_sum', # As above.

    # Features that are essentially flags of presence, not continuous values to trend (unless for very specific analyses)
    # Note: alcohol_consumed_daily_flag, had_breakfast etc. are included in features_to_lag because their daily presence
    # can directly influence next day's state.

    # Highly specific or possibly redundant metrics (often better handled by a composite score or other features)
    'avg_minutes_to_fall_asleep', # Covered by overall sleep metrics
    'avg_minutes_after_wakeup', # Covered by overall sleep metrics
    'avg_sleep_efficiency',     # Covered by overall sleep metrics
    'avg_composition_score',
    'avg_revitalization_score',
    'avg_duration_score',
    'total_minutes_awake_during_sleep', # Covered by total_minutes_asleep + total_time_in_bed
    'total_awake_minutes_in_sleep_stages', # Similar to minutesAwake

    # Count of sessions might be lagged if you want to predict frequency, but generally
    # the total duration/load are more indicative for well-being.
    'num_daily_srpe_sessions', # Already included in features_to_lag for potential impact.
    'num_exercise_sessions', # Already included in features_to_lag for potential impact.
]

# %%
df = calculate_lagged_features(df,features_to_lag,1)

# %%
df.shape
# Out:
# (144, 149)

# %% [markdown]
# ## dealing with newly introduced missing values

# %%
df.isna().sum().to_dict()
# Out:
# {'fatigue': 15,
#  'mood': 15,
#  'readiness': 15,
#  'soreness': 15,
#  'stress': 15,
#  'weight': 0,
#  'alcohol_consumed_daily_flag': 0,
#  'had_breakfast': 0,
#  'had_lunch': 0,
#  'had_dinner': 0,
#  'had_evening': 0,
#  'total_daily_training_load_srpe': 0,
#  'total_exercise_duration_minutes': 0,
#  'avg_exercise_heart_rate': 0,
#  'num_exercise_sessions': 0,
#  'total_minutes_asleep': 0,
#  'total_deep_sleep_minutes': 0,
#  'total_rem_sleep_minutes': 0,
#  'avg_overall_sleep_score': 0,
#  'avg_restlessness': 0,
#  'time_in_below_default_zone1_minutes_x': 0,
#  'time_in_fat_burn_zone_minutes_x': 0,
#  'time_in_cardio_zone_minutes_x': 0,
#  'time_in_peak_zone_minutes_x': 0,
#  'very_active_minutes_sum': 0,
#  'sedentary_minutes_sum': 0,
#  'lightly_active_minutes_sum': 0,
#  'avg_daily_heart_rate': 0,
#  'avg_overall_sleep_score_MA_7': 6,
#  'total_minutes_asleep_MA_7': 6,
#  'total_rem_sleep_minutes_MA_7': 6,
#  'total_deep_sleep_minutes_MA_7': 6,
#  'avg_restlessness_MA_7': 6,
#  'total_exercise_duration_minutes_MA_7': 6,
#  'avg_exercise_heart_rate_MA_7': 6,
#  'num_exercise_sessions_MA_7': 6,
#  'avg_daily_heart_rate_MA_7': 6,
#  'sedentary_minutes_sum_MA_7': 6,
#  'lightly_active_minutes_sum_MA_7': 6,
#  'very_active_minutes_sum_MA_7': 6,
#  'time_in_below_default_zone1_minutes_x_MA_7': 6,
#  'time_in_fat_burn_zone_minutes_x_MA_7': 6,
#  'time_in_cardio_zone_minutes_x_MA_7': 6,
#  'time_in_peak_zone_minutes_x_MA_7': 6,
#  'total_daily_training_load_srpe_MA_7': 6,
#  'avg_overall_sleep_score_MA_30': 29,
#  'total_minutes_asleep_MA_30': 29,
#  'total_rem_sleep_minutes_MA_30': 29,
#  'total_deep_sleep_minutes_MA_30': 29,
#  'avg_restlessness_MA_30': 29,
#  'total_exercise_duration_minutes_MA_30': 29,
#  'avg_exercise_heart_rate_MA_30': 29,
#  'num_exercise_sessions_MA_30': 29,
#  'avg_daily_heart_rate_MA_30': 29,
#  'sedentary_minutes_sum_MA_30': 29,
#  'lightly_active_minutes_sum_MA_30': 29,
#  'very_active_minutes_sum_MA_30': 29,
#  'time_in_below_default_zone1_minutes_x_MA_30': 29,
#  'time_in_fat_burn_zone_minutes_x_MA_30': 29,
#  'time_in_cardio_zone_minutes_x_MA_30': 29,
#  'time_in_peak_zone_minutes_x_MA_30': 29,
#  'total_daily_training_load_srpe_MA_30': 29,
#  'avg_overall_sleep_score_delta_day_over_day': 1,
#  'total_minutes_asleep_delta_day_over_day': 1,
#  'total_rem_sleep_minutes_delta_day_over_day': 1,
#  'total_deep_sleep_minutes_delta_day_over_day': 1,
#  'avg_restlessness_delta_day_over_day': 1,
#  'total_exercise_duration_minutes_delta_day_over_day': 1,
#  'avg_exercise_heart_rate_delta_day_over_day': 1,
#  'num_exercise_sessions_delta_day_over_day': 1,
#  'avg_daily_heart_rate_delta_day_over_day': 1,
#  'sedentary_minutes_sum_delta_day_over_day': 1,
#  'lightly_active_minutes_sum_delta_day_over_day': 1,
#  'very_active_minutes_sum_delta_day_over_day': 1,
#  'time_in_below_default_zone1_minutes_x_delta_day_over_day': 1,
#  'time_in_fat_burn_zone_minutes_x_delta_day_over_day': 1,
#  'time_in_cardio_zone_minutes_x_delta_day_over_day': 1,
#  'time_in_peak_zone_minutes_x_delta_day_over_day': 1,
#  'total_daily_training_load_srpe_delta_day_over_day': 1,
#  'avg_overall_sleep_score_deviation_MA_7': 6,
#  'avg_overall_sleep_score_deviation_MA_30': 29,
#  'total_minutes_asleep_deviation_MA_7': 6,
#  'total_minutes_asleep_deviation_MA_30': 29,
#  'total_rem_sleep_minutes_deviation_MA_7': 6,
#  'total_rem_sleep_minutes_deviation_MA_30': 29,
#  'total_deep_sleep_minutes_deviation_MA_7': 6,
#  'total_deep_sleep_minutes_deviation_MA_30': 29,
#  'avg_restlessness_deviation_MA_7': 6,
#  'avg_restlessness_deviation_MA_30': 29,
#  'total_exercise_duration_minutes_deviation_MA_7': 6,
#  'total_exercise_duration_minutes_deviation_MA_30': 29,
#  'avg_exercise_heart_rate_deviation_MA_7': 6,
#  'avg_exercise_heart_rate_deviation_MA_30': 29,
#  'num_exercise_sessions_deviation_MA_7': 6,
#  'num_exercise_sessions_deviation_MA_30': 29,
#  'avg_daily_heart_rate_deviation_MA_7': 6,
#  'avg_daily_heart_rate_deviation_MA_30': 29,
#  'sedentary_minutes_sum_deviation_MA_7': 6,
#  'sedentary_minutes_sum_deviation_MA_30': 29,
#  'lightly_active_minutes_sum_deviation_MA_7': 6,
#  'lightly_active_minutes_sum_deviation_MA_30': 29,
#  'very_active_minutes_sum_deviation_MA_7': 6,
#  'very_active_minutes_sum_deviation_MA_30': 29,
#  'time_in_below_default_zone1_minutes_x_deviation_MA_7': 6,
#  'time_in_below_default_zone1_minutes_x_deviation_MA_30': 29,
#  'time_in_fat_burn_zone_minutes_x_deviation_MA_7': 6,
#  'time_in_fat_burn_zone_minutes_x_deviation_MA_30': 29,
#  'time_in_cardio_zone_minutes_x_deviation_MA_7': 6,
#  'time_in_cardio_zone_minutes_x_deviation_MA_30': 29,
#  'time_in_peak_zone_minutes_x_deviation_MA_7': 6,
#  'time_in_peak_zone_minutes_x_deviation_MA_30': 29,
#  'total_daily_training_load_srpe_deviation_MA_7': 6,
#  'total_daily_training_load_srpe_deviation_MA_30': 29,
#  'fatigue_lag1': 15,
#  'mood_lag1': 15,
#  'readiness_lag1': 15,
#  'soreness_lag1': 15,
#  'stress_lag1': 15,
#  'total_minutes_asleep_lag1': 1,
#  'total_deep_sleep_minutes_lag1': 1,
#  'total_rem_sleep_minutes_lag1': 1,
#  'avg_overall_sleep_score_lag1': 1,
#  'avg_restlessness_lag1': 1,
#  'avg_daily_heart_rate_lag1': 1,
#  'total_exercise_duration_minutes_lag1': 1,
#  'avg_exercise_heart_rate_lag1': 1,
#  'num_exercise_sessions_lag1': 1,
#  'sedentary_minutes_sum_lag1': 1,
#  'lightly_active_minutes_sum_lag1': 1,
#  'very_active_minutes_sum_lag1': 1,
#  'time_in_below_default_zone1_minutes_x_lag1': 1,
#  'time_in_fat_burn_zone_minutes_x_lag1': 1,
#  'time_in_cardio_zone_minutes_x_lag1': 1,
#  'time_in_peak_zone_minutes_x_lag1': 1,
#  'total_daily_training_load_srpe_lag1': 1,
#  'weight_lag1': 1,
#  'alcohol_consumed_daily_flag_lag1': 1,
#  'had_breakfast_lag1': 1,
#  'had_lunch_lag1': 1,
#  'had_dinner_lag1': 1,
#  'had_evening_lag1': 1,
#  'avg_overall_sleep_score_delta_day_over_day_lag1': 2,
#  'avg_daily_heart_rate_delta_day_over_day_lag1': 2,
#  'total_exercise_duration_minutes_delta_day_over_day_lag1': 2,
#  'total_daily_training_load_srpe_delta_day_over_day_lag1': 2,
#  'avg_overall_sleep_score_deviation_MA_7_lag1': 7,
#  'avg_daily_heart_rate_deviation_MA_7_lag1': 7,
#  'total_exercise_duration_minutes_deviation_MA_7_lag1': 7,
#  'total_daily_training_load_srpe_deviation_MA_7_lag1': 7}

# %% [markdown]
# Step 3: Conduct Initial Driver Analysis
# With a clean and feature-rich dataset, you can now move from diagnosing data to extracting insights. The goal is to understand what factors are most impactful for this individual's mental health.
#
# Action: Run a Feature Importance Analysis. Use a tree-based model, such as a RandomForestRegressor, which is robust and excellent for this purpose.
# Set up the model:
# Your target variable (y) will be a column like mood.
# Your feature set (X) will include the "Physiological Bedrock" features, the newly created "Deviation" features, and the "Lagged" features.
# Crucially, you must train the model only on the rows where mood is not null.
# The Outcome: The goal is not to achieve a perfect prediction score. The primary output you need is the feature importance scores. This will give you a ranked list of which factors (e.g., sleep_score_lag1, sedentary_minutes, heart_rate_deviation) are the most powerful predictors of the target variable. This is a cornerstone clinical insight. <br>
# Step 4: Begin Prototyping the Dashboard Views
# All the previous steps feed directly into the design of your Power BI dashboard. You now have the clean data and engineered features ready to be visualized.
#
# The "Long-Term Trends" View: This view will be built using the 28-day moving averages of key metrics like mood, stress, sleep score, and resting heart rate. These will provide a smooth, high-level overview of the user's progress over months.
# The "Daily & Weekly Detail" View: This view will use the 7-day moving averages overlaid on the daily raw values. This is where you can visualize the relationships discovered in your driver analysis, such as plotting mood against sleep_score_lag1.
# The "Flags & Anomalies" View: This view will be powered by your "Delta" and "Deviation" features. You can create KPI cards or a table that highlights significant events, such as "Heart rate was 15% above average today" or "Sleep score dropped more than 20 points from yesterday." This provides clinicians with immediate, actionable red flags.
