# %%
import pandas as pd

from src.data_cleaning import (
    create_merged_df
)

from src.data_engineering import (
    calculate_rolling_baselines,
    engineer_target_variable,
    add_risk_scores,
    generate_mock_appointments
)

from src.config import (
    RISK_THRESHOLD,
    LOOKAHEAD_DAYS,
    SUBJECTIVE_COLS,
    PHYSIOLOGICAL_CONFIG,
    participant_information
)

# %%
[participant_id for participant_id in participant_information.keys()]
# Out:
# ['60301085', '60107567', '60300310']

# %%
# loop over participant IDs and create a DataFrame for each and then combine all in one DataFrame
dfs = [create_merged_df(participant_id) for participant_id in participant_information.keys()]
df_final = pd.concat(dfs, ignore_index=True)

# %%
df_final
# Out:
#     participant_id   dateTime  resting_heart_rate  avg_overall_sleep_score  \
# 0         60301085 2019-11-05                 NaN                      NaN
# 1         60301085 2019-11-06                 NaN                      NaN
# 2         60301085 2019-11-07           55.667916                      NaN
# 3         60301085 2019-11-08           53.800657                     82.0
# 4         60301085 2019-11-09           53.646626                     76.0
# ..             ...        ...                 ...                      ...
# 438       60300310 2020-03-27           57.553473                     75.0
# 439       60300310 2020-03-28           58.318448                     75.0
# 440       60300310 2020-03-29           60.342356                     76.0
# 441       60300310 2020-03-30           58.196049                     88.0
# 442       60300310 2020-03-31           58.080897                     88.0
#
#      fatigue  mood  stress  sleep_quality  very_active_minutes_sum  \
# 0        NaN   NaN     NaN            NaN                        0
# 1        3.0   3.0     5.0            4.0                       65
# 2        4.0   3.0     4.0            4.0                      105
# 3        3.0   3.0     3.0            4.0                       29
# 4        4.0   4.0     4.0            4.0                      324
# ..       ...   ...     ...            ...                      ...
# 438      4.0   3.0     2.0            4.0                        0
# 439      4.0   3.0     2.0            4.0                       22
# 440      4.0   3.0     2.0            4.0                        2
# 441      4.0   4.0     4.0            3.0                        0
# 442      4.0   4.0     4.0            3.0                        0
#
#      sedentary_minutes_sum
# 0                     1440
# 1                     1270
# 2                      563
# 3                      660
# 4                      383
# ..                     ...
# 438                    855
# 439                   1130
# 440                    808
# 441                    748
# 442                    998
#
# [443 rows x 10 columns]

# %%
df_final = calculate_rolling_baselines(df_final, ["resting_heart_rate","avg_overall_sleep_score"],dateTime_column= "dateTime", window_size=14, calculate_mean=True, calculate_std=True)

# %%
df_final.head()
# Out:
#            participant_id   dateTime  resting_heart_rate  \
# dateTime
# 2019-11-15       60107567 2019-11-15           53.468737
# 2019-11-16       60107567 2019-11-16           54.426253
# 2019-11-16       60301085 2019-11-16           55.303761
# 2019-11-16       60300310 2019-11-16           60.384912
# 2019-11-17       60107567 2019-11-17           53.575249
#
#             avg_overall_sleep_score  fatigue  mood  stress  sleep_quality  \
# dateTime
# 2019-11-15                     76.0      2.0   4.0     4.0            4.0
# 2019-11-16                     75.0      3.0   4.0     4.0            3.0
# 2019-11-16                     80.0      3.0   3.0     4.0            3.0
# 2019-11-16                     81.0      5.0   4.0     2.0            5.0
# 2019-11-17                     83.0      2.0   3.0     3.0            2.0
#
#             very_active_minutes_sum  sedentary_minutes_sum  \
# dateTime
# 2019-11-15                       99                    613
# 2019-11-16                      111                    546
# 2019-11-16                      139                    513
# 2019-11-16                       34                    536
# 2019-11-17                      106                    573
#
#             resting_heart_rate_14_mean  resting_heart_rate_14_std  \
# dateTime
# 2019-11-15                   55.313041                   3.504222
# 2019-11-16                   54.852928                   3.120667
# 2019-11-16                   55.044874                   3.054470
# 2019-11-16                   55.582254                   3.293276
# 2019-11-17                   55.697496                   3.183232
#
#             avg_overall_sleep_score_14_mean  avg_overall_sleep_score_14_std
# dateTime
# 2019-11-15                        76.142857                       10.316955
# 2019-11-16                        75.071429                        9.514881
# 2019-11-16                        74.642857                        9.111338
# 2019-11-16                        74.857143                        9.230861
# 2019-11-17                        75.642857                        9.434855

# %%
df_final = add_risk_scores(df_final, 
                subjective_cols_config = SUBJECTIVE_COLS,
                physiological_cols_config=PHYSIOLOGICAL_CONFIG)
# Out:
# Successfully calculated and appended daily risk scores using refactored functions.

# %%
df_final
# Out:
#            participant_id   dateTime  resting_heart_rate  \
# dateTime
# 2019-11-15       60107567 2019-11-15           53.468737
# 2019-11-16       60107567 2019-11-16           54.426253
# 2019-11-16       60301085 2019-11-16           55.303761
# 2019-11-16       60300310 2019-11-16           60.384912
# 2019-11-17       60107567 2019-11-17           53.575249
# ...                   ...        ...                 ...
# 2020-03-30       60300310 2020-03-30           58.196049
# 2020-03-30       60301085 2020-03-30           55.178128
# 2020-03-31       60107567 2020-03-31           53.567041
# 2020-03-31       60301085 2020-03-31           55.457790
# 2020-03-31       60300310 2020-03-31           58.080897
#
#             avg_overall_sleep_score  fatigue  mood  stress  sleep_quality  \
# dateTime
# 2019-11-15                     76.0      2.0   4.0     4.0            4.0
# 2019-11-16                     75.0      3.0   4.0     4.0            3.0
# 2019-11-16                     80.0      3.0   3.0     4.0            3.0
# 2019-11-16                     81.0      5.0   4.0     2.0            5.0
# 2019-11-17                     83.0      2.0   3.0     3.0            2.0
# ...                             ...      ...   ...     ...            ...
# 2020-03-30                     88.0      4.0   4.0     4.0            3.0
# 2020-03-30                     88.0      3.0   3.0     3.0            3.0
# 2020-03-31                     72.0      2.0   4.0     4.0            2.0
# 2020-03-31                     88.0      3.0   3.0     3.0            3.0
# 2020-03-31                     88.0      4.0   4.0     4.0            3.0
#
#             very_active_minutes_sum  sedentary_minutes_sum  \
# dateTime
# 2019-11-15                       99                    613
# 2019-11-16                      111                    546
# 2019-11-16                      139                    513
# 2019-11-16                       34                    536
# 2019-11-17                      106                    573
# ...                             ...                    ...
# 2020-03-30                        0                    748
# 2020-03-30                       15                    496
# 2020-03-31                       95                    665
# 2020-03-31                       67                    387
# 2020-03-31                        0                    998
#
#             resting_heart_rate_14_mean  resting_heart_rate_14_std  \
# dateTime
# 2019-11-15                   55.313041                   3.504222
# 2019-11-16                   54.852928                   3.120667
# 2019-11-16                   55.044874                   3.054470
# 2019-11-16                   55.582254                   3.293276
# 2019-11-17                   55.697496                   3.183232
# ...                                ...                        ...
# 2020-03-30                   56.320251                   2.763394
# 2020-03-30                   56.088858                   2.709362
# 2020-03-31                   55.800677                   2.750342
# 2020-03-31                   56.023167                   2.569128
# 2020-03-31                   56.060840                   2.597010
#
#             avg_overall_sleep_score_14_mean  avg_overall_sleep_score_14_std  \
# dateTime
# 2019-11-15                        76.142857                       10.316955
# 2019-11-16                        75.071429                        9.514881
# 2019-11-16                        74.642857                        9.111338
# 2019-11-16                        74.857143                        9.230861
# 2019-11-17                        75.642857                        9.434855
# ...                                     ...                             ...
# 2020-03-30                        78.357143                        4.125104
# 2020-03-30                        79.071429                        4.859001
# 2020-03-31                        78.357143                        5.123207
# 2020-03-31                        79.142857                        5.709064
# 2020-03-31                        80.071429                        6.031511
#
#             Subjective_Distress_Score  Physiological_Deviation_Score
# dateTime
# 2019-11-15                          1                              0
# 2019-11-16                          0                              0
# 2019-11-16                          0                              0
# 2019-11-16                          1                              1
# 2019-11-17                          2                              0
# ...                               ...                            ...
# 2020-03-30                          0                              0
# 2020-03-30                          0                              0
# 2020-03-31                          2                              1
# 2020-03-31                          0                              0
# 2020-03-31                          0                              0
#
# [412 rows x 16 columns]

# %%
df_final = engineer_target_variable(df_final, risk_threshold=RISK_THRESHOLD, lookahead_window=LOOKAHEAD_DAYS)

# %%
df_final.columns
# Out:
# Index(['participant_id', 'dateTime', 'resting_heart_rate',
#        'avg_overall_sleep_score', 'fatigue', 'mood', 'stress', 'sleep_quality',
#        'very_active_minutes_sum', 'sedentary_minutes_sum',
#        'resting_heart_rate_14_mean', 'resting_heart_rate_14_std',
#        'avg_overall_sleep_score_14_mean', 'avg_overall_sleep_score_14_std',
#        'Subjective_Distress_Score', 'Physiological_Deviation_Score',
#        'Composite_Risk_Score', 'High_Risk_State', 'Is_High_Risk_Next_7_Days'],
#       dtype='object')

# %%
df_final.to_csv("cleaned_data/many_participants_v2.csv", index=False)

# %%
df_final
# Out:
#            participant_id   dateTime  resting_heart_rate  \
# dateTime
# 2019-11-15       60107567 2019-11-15           53.468737
# 2019-11-16       60107567 2019-11-16           54.426253
# 2019-11-16       60301085 2019-11-16           55.303761
# 2019-11-16       60300310 2019-11-16           60.384912
# 2019-11-17       60107567 2019-11-17           53.575249
# ...                   ...        ...                 ...
# 2020-03-30       60300310 2020-03-30           58.196049
# 2020-03-30       60301085 2020-03-30           55.178128
# 2020-03-31       60107567 2020-03-31           53.567041
# 2020-03-31       60301085 2020-03-31           55.457790
# 2020-03-31       60300310 2020-03-31           58.080897
#
#             avg_overall_sleep_score  fatigue  mood  stress  sleep_quality  \
# dateTime
# 2019-11-15                     76.0      2.0   4.0     4.0            4.0
# 2019-11-16                     75.0      3.0   4.0     4.0            3.0
# 2019-11-16                     80.0      3.0   3.0     4.0            3.0
# 2019-11-16                     81.0      5.0   4.0     2.0            5.0
# 2019-11-17                     83.0      2.0   3.0     3.0            2.0
# ...                             ...      ...   ...     ...            ...
# 2020-03-30                     88.0      4.0   4.0     4.0            3.0
# 2020-03-30                     88.0      3.0   3.0     3.0            3.0
# 2020-03-31                     72.0      2.0   4.0     4.0            2.0
# 2020-03-31                     88.0      3.0   3.0     3.0            3.0
# 2020-03-31                     88.0      4.0   4.0     4.0            3.0
#
#             very_active_minutes_sum  sedentary_minutes_sum  \
# dateTime
# 2019-11-15                       99                    613
# 2019-11-16                      111                    546
# 2019-11-16                      139                    513
# 2019-11-16                       34                    536
# 2019-11-17                      106                    573
# ...                             ...                    ...
# 2020-03-30                        0                    748
# 2020-03-30                       15                    496
# 2020-03-31                       95                    665
# 2020-03-31                       67                    387
# 2020-03-31                        0                    998
#
#             resting_heart_rate_14_mean  resting_heart_rate_14_std  \
# dateTime
# 2019-11-15                   55.313041                   3.504222
# 2019-11-16                   54.852928                   3.120667
# 2019-11-16                   55.044874                   3.054470
# 2019-11-16                   55.582254                   3.293276
# 2019-11-17                   55.697496                   3.183232
# ...                                ...                        ...
# 2020-03-30                   56.320251                   2.763394
# 2020-03-30                   56.088858                   2.709362
# 2020-03-31                   55.800677                   2.750342
# 2020-03-31                   56.023167                   2.569128
# 2020-03-31                   56.060840                   2.597010
#
#             avg_overall_sleep_score_14_mean  avg_overall_sleep_score_14_std  \
# dateTime
# 2019-11-15                        76.142857                       10.316955
# 2019-11-16                        75.071429                        9.514881
# 2019-11-16                        74.642857                        9.111338
# 2019-11-16                        74.857143                        9.230861
# 2019-11-17                        75.642857                        9.434855
# ...                                     ...                             ...
# 2020-03-30                        78.357143                        4.125104
# 2020-03-30                        79.071429                        4.859001
# 2020-03-31                        78.357143                        5.123207
# 2020-03-31                        79.142857                        5.709064
# 2020-03-31                        80.071429                        6.031511
#
#             Subjective_Distress_Score  Physiological_Deviation_Score  \
# dateTime
# 2019-11-15                          1                              0
# 2019-11-16                          0                              0
# 2019-11-16                          0                              0
# 2019-11-16                          1                              1
# 2019-11-17                          2                              0
# ...                               ...                            ...
# 2020-03-30                          0                              0
# 2020-03-30                          0                              0
# 2020-03-31                          2                              1
# 2020-03-31                          0                              0
# 2020-03-31                          0                              0
#
#             Composite_Risk_Score  High_Risk_State  Is_High_Risk_Next_7_Days
# dateTime
# 2019-11-15                     1                0                         0
# 2019-11-16                     0                0                         1
# 2019-11-16                     0                0                         1
# 2019-11-16                     2                0                         1
# 2019-11-17                     2                0                         1
# ...                          ...              ...                       ...
# 2020-03-30                     0                0                         1
# 2020-03-30                     0                0                         1
# 2020-03-31                     3                1                         0
# 2020-03-31                     0                0                         0
# 2020-03-31                     0                0                        -1
#
# [412 rows x 19 columns]

# %%
df_final["Composite_Risk_Score"]
# Out:
# dateTime
# 2019-11-15    1
# 2019-11-16    0
# 2019-11-16    0
# 2019-11-16    2
# 2019-11-17    2
#              ..
# 2020-03-30    0
# 2020-03-30    0
# 2020-03-31    3
# 2020-03-31    0
# 2020-03-31    0
# Name: Composite_Risk_Score, Length: 412, dtype: int64

# %%
# Get start and end dates for each participant
start_dates = df_final.groupby("participant_id")["dateTime"].min().dt.date.to_dict()
end_dates = df_final.groupby("participant_id")["dateTime"].max().dt.date.to_dict()

# %%
all_appointments = []
for participant_id in participant_information.keys():
    start_date = str(start_dates.get(participant_id, None))
    end_date = str(end_dates.get(participant_id, None))
    appointments = generate_mock_appointments(participant_id, start_date, end_date)
    all_appointments.extend(appointments)
# Out:
# Generating mock data for 60301085 participant
# Generating mock data for 60107567 participant
# Generating mock data for 60300310 participant

# %%
all_appointments
# convert all_appointments to a DataFrame
# Out:
# [{'participant_id': '60301085',
#   'AppointmentDate': datetime.date(2020, 1, 22),
#   'Status': 'Cancelled'},
#  {'participant_id': '60301085',
#   'AppointmentDate': datetime.date(2019, 11, 26),
#   'Status': 'Attended'},
#  {'participant_id': '60301085',
#   'AppointmentDate': datetime.date(2019, 12, 17),
#   'Status': 'Attended'},
#  {'participant_id': '60301085',
#   'AppointmentDate': datetime.date(2020, 1, 15),
#   'Status': 'Cancelled'},
#  {'participant_id': '60107567',
#   'AppointmentDate': datetime.date(2020, 3, 21),
#   'Status': 'Cancelled'},
#  {'participant_id': '60107567',
#   'AppointmentDate': datetime.date(2020, 2, 27),
#   'Status': 'Attended'},
#  {'participant_id': '60107567',
#   'AppointmentDate': datetime.date(2020, 3, 19),
#   'Status': 'Cancelled'},
#  {'participant_id': '60107567',
#   'AppointmentDate': datetime.date(2020, 1, 31),
#   'Status': 'Cancelled'},
#  {'participant_id': '60107567',
#   'AppointmentDate': datetime.date(2020, 1, 25),
#   'Status': 'Attended'},
#  {'participant_id': '60107567',
#   'AppointmentDate': datetime.date(2019, 11, 17),
#   'Status': 'Attended'},
#  {'participant_id': '60107567',
#   'AppointmentDate': datetime.date(2019, 11, 16),
#   'Status': 'Attended'},
#  {'participant_id': '60300310',
#   'AppointmentDate': datetime.date(2020, 3, 12),
#   'Status': 'No-Show'},
#  {'participant_id': '60300310',
#   'AppointmentDate': datetime.date(2019, 12, 29),
#   'Status': 'Attended'},
#  {'participant_id': '60300310',
#   'AppointmentDate': datetime.date(2020, 1, 1),
#   'Status': 'Cancelled'},
#  {'participant_id': '60300310',
#   'AppointmentDate': datetime.date(2020, 2, 20),
#   'Status': 'Attended'},
#  {'participant_id': '60300310',
#   'AppointmentDate': datetime.date(2020, 3, 31),
#   'Status': 'Attended'},
#  {'participant_id': '60300310',
#   'AppointmentDate': datetime.date(2020, 2, 28),
#   'Status': 'Attended'},
#  {'participant_id': '60300310',
#   'AppointmentDate': datetime.date(2020, 1, 17),
#   'Status': 'Attended'},
#  {'participant_id': '60300310',
#   'AppointmentDate': datetime.date(2019, 12, 12),
#   'Status': 'Cancelled'}]

# %%
appointments_df = pd.DataFrame(all_appointments)
appointments_df["participant_id"].unique()
# Out:
# array(['60301085', '60107567', '60300310'], dtype=object)

# %%
appointments_df.to_csv("cleaned_data/appointments_v2.csv", index=False)
